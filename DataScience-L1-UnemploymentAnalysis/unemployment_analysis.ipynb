# %% [markdown]
# ## Conclusion
#
# ### Key Findings:
#
# - **Pandemic Impact**: The unemployment rate rose sharply during the COVID-19 pandemic, particularly during the lockdown period (March-August 2020).
#
# - **Regional Disparities**: Some states were more affected than others. Delhi experienced sudden spikes, while Maharashtra and Tamil Nadu showed more gradual changes.
#
# - **Unemployment Ranking**: Certain regions like Haryana and Tripura consistently showed higher unemployment compared to national averages, indicating structural employment challenges.
#
# - **Labour Market Relationships**: Unemployment and employment showed strong inverse relationships, confirming that job losses during the pandemic reduced total employment.
#
# - **Labour Participation**: The correlation with labour participation rate shows how economic stress affects workforce participation decisions.
#
# - **Recovery Patterns**: Post-2020 data shows gradual recovery, but different regions recovered at different rates, suggesting varying economic resilience.
#
# ### Recommendations:
#
# 1. **Targeted Interventions**: Focus policy interventions on high-unemployment regions like Haryana and Tripura.
# 2. **Skill Development**: Invest in skill development programs to address structural unemployment.
# 3. **Regional Policies**: Design region-specific economic recovery and employment generation schemes.
# 4. **Labour Force Participation**: Create initiatives to encourage workforce participation, especially post-pandemic.
# 5. **Monitoring**: Continue monitoring regional unemployment trends for early warning of labour market deterioration.

# %% [markdown]
# ### Observation
#
# The average unemployment rate increased significantly after the onset of COVID-19 due to lockdowns and reduced economic activity. This dramatic shift in the labour market highlights the severe immediate impact of the pandemic. The difference between pre-COVID and post-COVID periods clearly demonstrates how external shocks can disrupt employment patterns at the national level.

# %%
# Create comparison dataframe
comparison = pd.DataFrame({
    "Period": ["Pre-COVID", "Post-COVID"],
    "Average Unemployment Rate": [
        pre["Estimated Unemployment Rate (%)"].mean(),
        post["Estimated Unemployment Rate (%)"].mean()
    ]
})

# Bar chart
plt.figure(figsize=(8, 5))
sns.barplot(data=comparison, x="Period", y="Average Unemployment Rate", palette="Set2")
plt.title("Pre vs Post COVID Average Unemployment Rate", fontsize=14, fontweight='bold')
plt.ylabel("Average Unemployment Rate (%)")
plt.ylim(0, max(comparison["Average Unemployment Rate"]) * 1.15)

# Add value labels on bars
for i, v in enumerate(comparison["Average Unemployment Rate"]):
    plt.text(i, v + 0.1, f'{v:.2f}%', ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Split dataset into pre-COVID and post-COVID
pre = df[df["Date"] < "2020-03-01"]
post = df[df["Date"] >= "2020-03-01"]

# Calculate averages
print("Pre-COVID (Before March 2020):")
print(f"Average Unemployment Rate: {pre['Estimated Unemployment Rate (%)'].mean():.2f}%")
print(f"Average Employment Rate: {pre['Estimated Employed'].mean():.2f}")
print(f"Average Labour Participation Rate: {pre['Estimated Labour Participation Rate (%)'].mean():.2f}%")

print("\nPost-COVID (March 2020 onwards):")
print(f"Average Unemployment Rate: {post['Estimated Unemployment Rate (%)'].mean():.2f}%")
print(f"Average Employment Rate: {post['Estimated Employed'].mean():.2f}")
print(f"Average Labour Participation Rate: {post['Estimated Labour Participation Rate (%)'].mean():.2f}%")

# %% [markdown]
# ## 6) Pre-COVID vs Post-COVID Comparison
#
# COVID-19 started around March 2020. Let's compare labour market indicators before and after this date.

# %% [markdown]
# ### Observation
#
# The heatmap reveals important relationships:
# - **Negative correlation between unemployment and employment**: As unemployment increases, employment decreases (as expected)
# - **Labour participation relationship**: The correlation with labour participation shows how participation patterns shift during economic stress
# These relationships reinforce that rising unemployment coincided with weaker employment conditions overall.

# %%
# Plot correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", cbar_kws={'label': 'Correlation'})
plt.title("Correlation Heatmap: Labour Market Indicators", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Select numeric columns for correlation
corr = df[[
    "Estimated Unemployment Rate (%)",
    "Estimated Employed",
    "Estimated Labour Participation Rate (%)"
]].corr()

print("Correlation Matrix:")
print(corr)

# %% [markdown]
# ## 5) Correlation Heatmap
#
# Analyze the relationship between unemployment rate, employment rate, and labour participation rate.

# %% [markdown]
# ### Observation
#
# These regions consistently recorded higher unemployment levels compared to the national average. This suggests structural unemployment issues, skill mismatch, or industries that were severely impacted by the pandemic in these areas. Policy interventions and targeted employment schemes could be beneficial for these regions.

# %%
# Plot top 10 states
plt.figure(figsize=(10, 6))
sns.barplot(x=top10.values, y=top10.index, palette="rocket")
plt.title("Top 10 States/Regions with Highest Average Unemployment", fontsize=14, fontweight='bold')
plt.xlabel("Average Unemployment Rate (%)")
plt.ylabel("Region")
plt.tight_layout()
plt.show()

# %%
# Calculate average unemployment by region
region_avg_full = df.groupby("Region")["Estimated Unemployment Rate (%)"].mean().sort_values(ascending=False)

# Get top 10
top10 = region_avg_full.head(10)
print("Top 10 Regions with Highest Average Unemployment:")
print(top10)

# %% [markdown]
# ## 4) Top 10 States with Highest Average Unemployment

# %% [markdown]
# ### Observation
#
# Delhi experienced a sudden spike in unemployment during COVID-19, while Maharashtra and Tamil Nadu showed more gradual changes. This variation highlights how different states experienced the pandemic differently based on their economic structure and policy responses. Recovery patterns also differed across states.

# %%
# Time series for major states
states = ["Maharashtra", "Delhi", "Tamil Nadu"]

plt.figure(figsize=(14, 6))
for state in states:
    temp = df[df["Region"] == state]
    plt.plot(temp["Date"], temp["Estimated Unemployment Rate (%)"], label=state, marker='o', linewidth=2)

plt.legend(fontsize=10)
plt.title("Unemployment Rate Over Time for Major States", fontsize=14, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("Unemployment Rate (%)")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3) Time Series for Major States
#
# Compare unemployment trends across three major states to understand regional variations in pandemic impact.

# %% [markdown]
# ### Observation
#
# The monthly trend shows a clear seasonal pattern with peaks and troughs throughout the year. Most notably, the unemployment rate increased sharply during the nationwide COVID-19 lockdown period (particularly around March-April 2020) and gradually declined afterward as economic activities resumed.

# %%
# Plot month-wise unemployment trend
plt.figure(figsize=(10, 5))
month_avg.plot(marker='o', color='coral', linewidth=2, markersize=8)
plt.title("Month-wise Average Unemployment Rate", fontsize=14, fontweight='bold')
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Create Month column
df['Month'] = df['Date'].dt.month_name()

# Calculate average unemployment for each month
month_avg = df.groupby("Month")["Estimated Unemployment Rate (%)"].mean()

# Reorder months chronologically
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']
month_avg = month_avg.reindex(month_order)

print("Month-wise Average Unemployment Rate:")
print(month_avg)

# %% [markdown]
# ## 2) Month-wise Trend
#
# Analyze how unemployment rates vary across different months to identify seasonal patterns.

# %% [markdown]
# ### Observation
#
# The chart shows that certain regions like Haryana and Tripura have comparatively higher unemployment rates, while others like Meghalaya and Odisha have relatively lower unemployment rates. This indicates regional disparities in employment opportunities and economic conditions across India.

# %%
# Plot region-wise unemployment rates
plt.figure(figsize=(12, 6))
region_avg.plot(kind="barh", color="steelblue")
plt.title("Average Unemployment Rate by Region", fontsize=14, fontweight='bold')
plt.xlabel("Average Unemployment Rate (%)")
plt.ylabel("Region")
plt.tight_layout()
plt.show()

# %%
# Calculate region-wise average unemployment rate
region_avg = df.groupby("Region")["Estimated Unemployment Rate (%)"].mean()

# Sort in descending order
region_avg = region_avg.sort_values(ascending=False)
print("Region-wise Average Unemployment Rate:")
print(region_avg)

# %% [markdown]
# ## 1) Region-wise Average Unemployment Rate
#
# Calculate the average unemployment rate for each region to identify which regions had the highest unemployment levels during the study period.

# %%
# Convert Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Verify conversion
print("Data types after conversion:")
print(df.info())

# %%
# Null values
print("Null Values:")
print(df.isnull().sum())
print("\n" + "="*50 + "\n")

# %%
# Data Information
print("Data Information:")
print(df.info())
print("\n" + "="*50 + "\n")

# %%
# First 5 rows
print("First 5 rows:")
print(df.head())
print("\n" + "="*50 + "\n")

# %%
# Inspect Data - Shape
print("Dataset Shape:")
print(df.shape)
print("\n" + "="*50 + "\n")

# %%
# Load Dataset
# Make sure "Unemployment in India.csv" is in the same folder as this notebook
df = pd.read_csv("Unemployment in India.csv")

# %%
# Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# # Unemployment Analysis in India
#
# **Objective:** Perform exploratory data analysis on unemployment data to uncover regional and temporal trends, with a focus on the impact of the COVID-19 pandemic on unemployment rates in India.
#
# **Tech Stack:** Python, pandas, matplotlib, seaborn, Jupyter Notebook
